# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Q:/Datasets/Covid19_India/StatewiseTestingDetails.csv")

# %%
data.head()
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
data.tail()
# Out:
#             Date        State  TotalSamples Negative  Positive
# 4601  2020-08-23  West Bengal     1561311.0      NaN       NaN
# 4602  2020-08-24  West Bengal     1596578.0      NaN       NaN
# 4603  2020-08-25  West Bengal     1634102.0      NaN       NaN
# 4604  2020-08-26  West Bengal     1674133.0      NaN       NaN
# 4605  2020-08-27  West Bengal     1716607.0      NaN       NaN

# %%
data.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
data.describe()
# Out:
#        TotalSamples       Positive
# count  4.606000e+03    4255.000000
# mean   3.528032e+05   19426.973913
# std    6.370249e+05   53697.041408
# min    5.800000e+01       0.000000
# 25%    1.665325e+04     251.000000
# 50%    8.189200e+04    1921.000000
# 75%    3.958250e+05   12375.000000
# max    5.080205e+06  607631.000000

# %%
data.isnull().sum()
# Out:
# Date               0
# State              0
# TotalSamples       0
# Negative        1753
# Positive         351
# dtype: int64

# %% [markdown]
# ## Relating the variables with scatterplots

# %%
data.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
sns.relplot(x='TotalSamples', y='State', data=data)

# %%
sns.relplot(x='Positive', y='State', data=data)

# %%
sns.relplot(x='Negative', y='State', data=data)

# %%
sns.pairplot(data)
